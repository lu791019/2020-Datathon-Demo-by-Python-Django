# %%
#import pymssql
import pandas as pd
import numpy as np
import pyodbc
import datetime as dt

# %%
import pyodbc
server='datathon.database.windows.net'
database = 'datathon_mssql' 
username = 'datathonuser' 
password = '1qaz@WSX3edc' 
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = conn.cursor()

# %%
sql = '''

SELECT frequency_lt from drink_bad_rfm

'''

prefer_food = pd.read_sql(sql, conn)
prefer_food
# Out:
#       frequency_lt
# 0              2.0
# 1              2.0
# 2              2.0
# 3              4.0
# 4              8.0
# ...            ...
# 2833           2.0
# 2834           2.0
# 2835           6.0
# 2836          12.0
# 2837          12.0
#
# [2838 rows x 1 columns]

# %%
prefer_food.plot.hist(bins=300, alpha=1)

# %%
query = " SELECT frequency_lt, member_serial from drink_bad_rfm "
cursor.execute(query)

# %%
data = list(cursor)

# %%
data
# Out:
# [(Decimal('2'), '0002a4db595bbe07e63b89b6c039bd88013b6ddd'),
#  (Decimal('2'), '0014b2b7729e0e2c133a2ad243ba3429017001d2'),
#  (Decimal('2'), '003ed961444ff4cd6108802fd3032e7f9d112bc9'),
#  (Decimal('4'), '003f066281191cef4d54cb2cfa82966c777e31c6'),
#  (Decimal('8'), '006aea55428c94cdb4f2bbad6e97ae35ae00e8d5'),
#  (Decimal('2'), '006c280f3641409a5a63be18ca7f4f5c761c9944'),
#  (Decimal('4'), '006d9b93783bc9735bbba1e13ce9c4eec080cbaa'),
#  (Decimal('2'), '0076fede69e896fd7ae0b028cee122d4c025ae9b'),
#  (Decimal('2'), '00af37202c1c4db571950fede1a4eea58fe4ecac'),
#  (Decimal('4'), '00afa692f8d9541db020bea9235a5ee982456608'),
#  (Decimal('2'), '00c9faf8f10e95d9564491d2614acf25d45d763b'),
#  (Decimal('2'), '00d36710f3d31db3d15a2970791037ebb4d1dd9b'),
#  (Decimal('4'), '00e04760c5e92ac62711d5c8b538f7c76c71444a'),
#  (Decimal('10'), '00f6c6ac3cc5a83e34100d8c6f90718ee300b7d6'),
#  (Decimal('14'), '01066be8589455d577eff12692a7feb680582083'),
# ...
